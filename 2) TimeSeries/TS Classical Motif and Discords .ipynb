# %%
# %matplotlib inline

import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display
import utils

import warnings 
warnings.filterwarnings('always')   #suppresses all warnings
warnings.filterwarnings('ignore')

# %%
tracks= utils.load("/Users/david/Desktop/DM2 project/fma_metadata/tracks.csv")
tracks_cut=['album','artist']
tracks.drop(tracks_cut,axis=1,inplace=True)
tracks=tracks.droplevel(0,axis=1)
tracks.drop(index=tracks[tracks.subset=='large'].index, inplace=True)
tracks_cut=['composer','comments', 'date_created','date_recorded',
            'license','number','title','language_code',
            'publisher', 'tags','information','lyricist','genres','genres_all',
            'favorites','listens','interest','bit_rate', 'duration','split','subset']
tracks.drop(tracks_cut,axis=1,inplace=True)

# %% [raw]
# features= utils.load("/Users/david/Desktop/DM2 project/fma_metadata/features.csv")
# feat=features[['spectral_rolloff']]
# feat=feat.droplevel(0,axis=1)
# feat.columns=['roll_kurtosis','roll_max','roll_mean','roll_median','roll_min','roll_skew','roll_std']
# cut=['roll_kurtosis','roll_max','roll_std','roll_median','roll_min','roll_skew']
# feat.drop(cut,axis=1,inplace=True)

# %%
#estrazioni da librosa_mp3 di 10  secondi dopo i primi 10 features rolloff
ts=pd.read_csv("/Users/david/Desktop/DM2 project/fma_metadata/ts_centroid.csv")
ts.shape
# Out:
# (1028, 1209)

# %%
ts_df=pd.merge(tracks,ts, on='track_id')
ts_df.head()
# Out:
#    track_id            genre_top  Unnamed: 0  Unnamed: 0.1         0  \
# 0      4850            Classical          13           206  0.203188
# 1      4851            Classical          14           207  0.139737
# 2      5009  Old-Time / Historic          15           208  0.097878
# 3      5012  Old-Time / Historic          16           209  0.088058
# 4      5013  Old-Time / Historic          17           210  0.134297
#
#           1         2         3         4         5  ...      1196      1197  \
# 0  0.177222  0.170356  0.174893  0.181088  0.179945  ...  0.429477  0.438678
# 1  0.162770  0.188715  0.196280  0.222101  0.236519  ...  0.100511  0.092096
# 2  0.141881  0.181742  0.295769  0.343891  0.415385  ...  0.396982  0.354043
# 3  0.103542  0.167626  0.233723  0.334451  0.458624  ...  0.291008  0.467978
# 4  0.198303  0.286986  0.377489  0.289663  0.278561  ...  0.469473  0.409380
#
#        1198      1199      1200      1201      1202      1203      1204  \
# 0  0.423448  0.416010  0.414990  0.434620  0.557168  0.779985  0.852099
# 1  0.077473  0.062344  0.058620  0.039428  0.035532  0.036547  0.003289
# 2  0.370011  0.368628  0.309365  0.282796  0.272292  0.276301  0.301752
# 3  0.473676  0.195546  0.092509  0.263610  0.330493  0.367824  0.399824
# 4  0.320596  0.243092  0.350757  0.478701  0.517602  0.362054  0.187761
#
#        1205
# 0  0.806474
# 1  0.039476
# 2  0.270572
# 3  0.282295
# 4  0.319275
#
# [5 rows x 1210 columns]

# %% [markdown]
# # Check genres

# %%
tracks[tracks['genre_top']=='Old-Time / Historic'].head(2)
# Out:
#                     genre_top
# track_id
# 5009      Old-Time / Historic
# 5012      Old-Time / Historic

# %%
# find index from Old-Time / Historic track
ts_df.loc[ts_df.track_id == 5012]
# Out:
#    track_id            genre_top  Unnamed: 0  Unnamed: 0.1         0  \
# 3      5012  Old-Time / Historic          16           209  0.088058
#
#           1         2         3         4         5  ...      1196      1197  \
# 3  0.103542  0.167626  0.233723  0.334451  0.458624  ...  0.291008  0.467978
#
#        1198      1199      1200     1201      1202      1203      1204  \
# 3  0.473676  0.195546  0.092509  0.26361  0.330493  0.367824  0.399824
#
#        1205
# 3  0.282295
#
# [1 rows x 1210 columns]

# %%
tracks[tracks['genre_top']=='Classical'].head(2)
# Out:
#           genre_top
# track_id
# 4850      Classical
# 4851      Classical

# %%
# find index from Classical track
ts_df.loc[ts_df.track_id == 4850]
# Out:
#    track_id  genre_top  Unnamed: 0  Unnamed: 0.1         0         1  \
# 0      4850  Classical          13           206  0.203188  0.177222
#
#           2         3         4         5  ...      1196      1197      1198  \
# 0  0.170356  0.174893  0.181088  0.179945  ...  0.429477  0.438678  0.423448
#
#       1199     1200     1201      1202      1203      1204      1205
# 0  0.41601  0.41499  0.43462  0.557168  0.779985  0.852099  0.806474
#
# [1 rows x 1210 columns]

# %%
cut_columns=['track_id','Unnamed: 0','Unnamed: 0.1']
ts.drop(cut_columns, axis=1, inplace=True)

# %%
ts.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.203188  0.177222  0.170356  0.174893  0.181088  0.179945  0.180785
# 1  0.139737  0.162770  0.188715  0.196280  0.222101  0.236519  0.235485
# 2  0.097878  0.141881  0.181742  0.295769  0.343891  0.415385  0.524990
# 3  0.088058  0.103542  0.167626  0.233723  0.334451  0.458624  0.421045
# 4  0.134297  0.198303  0.286986  0.377489  0.289663  0.278561  0.435295
#
#           7         8         9  ...      1196      1197      1198      1199  \
# 0  0.181348  0.175140  0.177304  ...  0.429477  0.438678  0.423448  0.416010
# 1  0.234684  0.237329  0.223463  ...  0.100511  0.092096  0.077473  0.062344
# 2  0.526107  0.438027  0.430539  ...  0.396982  0.354043  0.370011  0.368628
# 3  0.172120  0.230144  0.366459  ...  0.291008  0.467978  0.473676  0.195546
# 4  0.430005  0.354197  0.245915  ...  0.469473  0.409380  0.320596  0.243092
#
#        1200      1201      1202      1203      1204      1205
# 0  0.414990  0.434620  0.557168  0.779985  0.852099  0.806474
# 1  0.058620  0.039428  0.035532  0.036547  0.003289  0.039476
# 2  0.309365  0.282796  0.272292  0.276301  0.301752  0.270572
# 3  0.092509  0.263610  0.330493  0.367824  0.399824  0.282295
# 4  0.350757  0.478701  0.517602  0.362054  0.187761  0.319275
#
# [5 rows x 1206 columns]

# %% [markdown]
# # Matrix Profile

# %%
from matrixprofile import *

# %%
#Classical track
ts1=ts.loc[[0]] 
ts2=ts.loc[[1]]

# %%
fig,ax = plt.subplots(1,2, figsize=(20,5))
ax[0].plot(np.squeeze(ts1.to_numpy().T))
ax[0].set_title('Old-Time/Historic')
ax[1].plot(np.squeeze(ts2.to_numpy().T))
ax[1].set_title('Classical')

plt.show()

# %%
w = 6
mp1, mpi1 = matrixProfile.stomp((np.squeeze(ts1.to_numpy()).T), w)
mp2, mpi2 =matrixProfile.stomp((np.squeeze(ts2.to_numpy()).T), w)


fig,ax=plt.subplots(1,2,figsize=(20,5))
ax[0].plot(mp1)
ax[0].set_title('Old-Time/Historic')
ax[1].plot(mp2)
ax[1].set_title('Classical')

plt.show()

# %%
w = 14
mp1, mpi1 = matrixProfile.stomp((np.squeeze(ts1.to_numpy()).T), w)
mp2, mpi2 =matrixProfile.stomp((np.squeeze(ts2.to_numpy()).T), w)

fig,ax=plt.subplots(1,2,figsize=(20,5))
ax[0].plot(mp1)
ax[0].set_title('Old-Time/Historic')
ax[1].plot(mp2)
ax[1].set_title('Classical')

plt.show()

# %% [markdown]
# # Motif Discovery

# %% [markdown]
# ## Old Time vs Classical

# %%
mo1, mod1  = motifs.motifs(np.squeeze(ts1.to_numpy().T), (mp1, mpi1), max_motifs=3)
mo2, mod2 = motifs.motifs(np.squeeze(ts2.to_numpy().T), (mp2,mpi2) ,max_motifs=3)

# %%
print('Old-Time / Historic motif:',mo1)
print('Classical motif:',mo2)
# Out:
# Old-Time / Historic motif: [[554, 638], [145, 499, 736, 1157], [330, 585, 623, 658, 861, 888, 1097]]
# Classical motif: [[418, 508, 529], [358, 474, 500, 757, 784, 837]]

# %%
print('Old-Time/Historic mod:',mod1)
print('Classical mod :',mod2)
# Out:
# Old-Time/Historic mod: [0.31813977451736764, 0.3504353734830415, 0.41558538169655657]
# Classical mod : [0.2953101995568336, 0.3638019452542598]

# %%
fig,ax=plt.subplots(2,1,figsize=(20,5))
ax[0].plot(np.squeeze(ts1.to_numpy().T))
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo1)]
for m, d, c in zip(mo1, mod1, colors):
    for i in m:
        m_shape = ts1.T.values[i:i+w]
        ax[0].plot(range(i,i+w), m_shape, color=c, lw=3)
        ax[0].set_title('Classical motifs')
ax[1].plot(np.squeeze(ts2.to_numpy().T))
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo2)]
for m, d, c in zip(mo2, mod2, colors):
    for i in m:
        m_shape = ts2.T.values[i:i+w]
        ax[1].plot(range(i,i+w), m_shape, color=c, lw=3)
        ax[1].set_title('Classical motifs')

plt.tight_layout()
plt.show()

# %% [raw]
# for m, d, c in zip(mo1, mod1, colors):
#     for i in m:
#         m_shape = ts1.values[i:i+w]
#         plt.plot(range(i,i+w), m_shape, color=c, lw=3)
#     plt.figure(figsize=(5,5))
#     plt.show()

# %% [raw]
# for m, d, c in zip(mo2, mod2, colors):
#     for i in m:
#         m_shape = ts2.values[i:i+w]
#         plt.plot(range(i,i+w), m_shape, color=c, lw=3)
#     plt.show()

# %% [markdown]
# # Anomaly Discovery

# %%
from matrixprofile.discords import discords

# %%
anoms1 = discords(mp1, ex_zone=3, k=3)
anoms2 = discords(mp2, ex_zone=3, k=3)

# %%
print('Old-Time/Historic discords:',anoms1)
print('Classical discords:',anoms2)
# Out:
# Old-Time/Historic discords: [877 763 239]
# Classical discords: [637 653 321]

# %%
fig,ax=plt.subplots(2,1,figsize=(20,5))
ax[0].plot(np.squeeze(ts1.to_numpy().T))
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo1)]
for a, c in zip(anoms1, colors):
    a_shape = ts1.T.values[a:a+w]
    ax[0].plot(range(a, a+w), a_shape, color=c, lw=3)
    ax[0].set_title('Old-Time/Historic discords')

ax[1].plot(np.squeeze(ts2.to_numpy().T))
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo2)]
for a, c in zip(anoms2, colors):
    a_shape = ts2.T.values[a:a+w]
    ax[1].plot(range(a, a+w), a_shape, color=c, lw=3)
    ax[1].set_title('Classical discords')
    
plt.tight_layout()    
plt.show()
